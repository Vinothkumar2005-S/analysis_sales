# %%
import pandas as pd

df = pd.read_csv(r"E:\data sets\sales_data_sample.csv", encoding="latin1", parse_dates = ['ORDER_DATE'])
df
# Out:
#       ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDERLINE_NUMBER    SALES  \
# 0            10107                30       95.70                 2  2871.00
# 1            10121                34       81.35                 5  2765.90
# 2            10134                41       94.74                 2  3884.34
# 3            10145                45       83.26                 6  3746.70
# 4            10159                49      100.00                14  5205.27
# ...            ...               ...         ...               ...      ...
# 2818         10350                20      100.00                15  2244.40
# 2819         10373                29      100.00                 1  3978.51
# 2820         10386                43      100.00                 4  5417.57
# 2821         10397                34       62.24                 1  2116.16
# 2822         10414                47       65.52                 9  3079.44
#
# ...

# %% [markdown]
# ## data exploring

# %%
df.head()
# Out:
#    ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDERLINE_NUMBER    SALES  \
# 0         10107                30       95.70                 2  2871.00
# 1         10121                34       81.35                 5  2765.90
# 2         10134                41       94.74                 2  3884.34
# 3         10145                45       83.26                 6  3746.70
# 4         10159                49      100.00                14  5205.27
#
#          ORDER_DATE   STATUS  QTR  MONTH  YEAR  ...  \
# 0    2/24/2003 0:00  Shipped    1      2  2003  ...
# 1  05-07-2003 00:00  Shipped    2      5  2003  ...
# 2  07-01-2003 00:00  Shipped    3      7  2003  ...
# 3    8/25/2003 0:00  Shipped    3      8  2003  ...
# 4  10-10-2003 00:00  Shipped    4     10  2003  ...
#
#                     ADDRESS_LINE  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# ...

# %%
df.describe()
# Out:
#        ORDER_NUMBER  QUANTITY_ORDERED   PRICE_EACH  ORDERLINE_NUMBER  \
# count   2823.000000       2823.000000  2823.000000       2823.000000
# mean   10258.725115         35.092809    83.658544          6.466171
# std       92.085478          9.741443    20.174277          4.225841
# min    10100.000000          6.000000    26.880000          1.000000
# 25%    10180.000000         27.000000    68.860000          3.000000
# 50%    10262.000000         35.000000    95.700000          6.000000
# 75%    10333.500000         43.000000   100.000000          9.000000
# max    10425.000000         97.000000   100.000000         18.000000
#
#               SALES          QTR        MONTH        YEAR         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# ...

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.columns
# Out:
# Index(['ORDER_NUMBER', 'QUANTITY_ORDERED', 'PRICE_EACH', 'ORDERLINE_NUMBER',
#        'SALES', 'ORDER_DATE', 'STATUS', 'QTR', 'MONTH', 'YEAR', 'PRODUCT_LINE',
#        'MSRP', 'PRODUCT_CODE', 'CUSTOMER_NAME', 'PHONE', 'ADDRESS_LINE',
#        'ADDRESSLINE2', 'CITY', 'STATE', 'POSTAL_CODE', 'COUNTRY', 'TERRITORY',
#        'CONTACT_LASTNAME', 'CONTACT_FIRSTNAME', 'DEAL_SIZE'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ORDER_NUMBER           int64
# QUANTITY_ORDERED       int64
# PRICE_EACH           float64
# ORDERLINE_NUMBER       int64
# SALES                float64
# ORDER_DATE            object
# STATUS                object
# QTR                    int64
# MONTH                  int64
# YEAR                   int64
# PRODUCT_LINE          object
# MSRP                   int64
# PRODUCT_CODE          object
# CUSTOMER_NAME         object
# PHONE                 object
# ADDRESS_LINE          object
# ADDRESSLINE2          object
# CITY                  object
# STATE                 object
# POSTAL_CODE           object
# COUNTRY               object
# TERRITORY             object
# CONTACT_LASTNAME      object
# CONTACT_FIRSTNAME     object
# DEAL_SIZE             object
# dtype: object

# %%
df.nunique()
# Out:
# ORDER_NUMBER          307
# QUANTITY_ORDERED       58
# PRICE_EACH           1016
# ORDERLINE_NUMBER       18
# SALES                2763
# ORDER_DATE            252
# STATUS                  6
# QTR                     4
# MONTH                  12
# YEAR                    3
# PRODUCT_LINE            7
# MSRP                   80
# PRODUCT_CODE          109
# CUSTOMER_NAME          92
# PHONE                  91
# ADDRESS_LINE           92
# ADDRESSLINE2            9
# CITY                   73
# STATE                  16
# POSTAL_CODE            73
# COUNTRY                19
# TERRITORY               3
# CONTACT_LASTNAME       77
# CONTACT_FIRSTNAME      72
# DEAL_SIZE               3
# dtype: int64

# %%
df.memory_usage()
# Out:
# Index                  132
# ORDER_NUMBER         22584
# QUANTITY_ORDERED     22584
# PRICE_EACH           22584
# ORDERLINE_NUMBER     22584
# SALES                22584
# ORDER_DATE           22584
# STATUS               22584
# QTR                  22584
# MONTH                22584
# YEAR                 22584
# PRODUCT_LINE         22584
# MSRP                 22584
# PRODUCT_CODE         22584
# CUSTOMER_NAME        22584
# PHONE                22584
# ADDRESS_LINE         22584
# ADDRESSLINE2         22584
# CITY                 22584
# STATE                22584
# POSTAL_CODE          22584
# COUNTRY              22584
# TERRITORY            22584
# CONTACT_LASTNAME     22584
# CONTACT_FIRSTNAME    22584
# DEAL_SIZE            22584
# dtype: int64

# %% [markdown]
# ## typecasting

# %%
df
# Out:
#       ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDERLINE_NUMBER    SALES  \
# 0            10107                30       95.70                 2  2871.00
# 1            10121                34       81.35                 5  2765.90
# 2            10134                41       94.74                 2  3884.34
# 3            10145                45       83.26                 6  3746.70
# 4            10159                49      100.00                14  5205.27
# ...            ...               ...         ...               ...      ...
# 2818         10350                20      100.00                15  2244.40
# 2819         10373                29      100.00                 1  3978.51
# 2820         10386                43      100.00                 4  5417.57
# 2821         10397                34       62.24                 1  2116.16
# 2822         10414                47       65.52                 9  3079.44
#
# ...

# %%
df['year'] = df['year'].astype(object)
df['year']
# Out:
# 0       2003
# 1       2003
# 2       2003
# 3       2003
# 4       2003
#         ...
# 2818    2004
# 2819    2005
# 2820    2005
# 2821    2005
# 2822    2005
# Name: year, Length: 2823, dtype: object

# %%
df['month'] = df['month'].astype(object)
df['month']
# Out:
# 0        2
# 1        5
# 2        7
# 3        8
# 4       10
#         ..
# 2818    12
# 2819     1
# 2820     3
# 2821     3
# 2822     5
# Name: month, Length: 2823, dtype: object

# %%
df['qtr'] = df['qtr'].astype(object)
df['qtr']
# Out:
# 0       1
# 1       2
# 2       3
# 3       3
# 4       4
#        ..
# 2818    4
# 2819    1
# 2820    1
# 2821    1
# 2822    2
# Name: qtr, Length: 2823, dtype: object

# %% [markdown]
# ## str functions

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['order_number', 'quantity_ordered', 'price_each', 'orderline_number',
#        'sales', 'order_date', 'status', 'qtr', 'month', 'year', 'product_line',
#        'msrp', 'product_code', 'customer_name', 'phone', 'address_line',
#        'addressline2', 'city', 'state', 'postal_code', 'country', 'territory',
#        'contact_lastname', 'contact_firstname', 'deal_size'],
#       dtype='object')

# %%
df2[df2['customer_name'].str.contains('Technics Stores Inc.')]
# Out:
#       order_number  quantity_ordered  price_each  orderline_number    sales  \
# 5            10168                36       96.66                 1  3479.76
# 29           10140                37      100.00                11  7374.10
# 59           10168                27      100.00                 4  3660.93
# 85           10168                20      100.00                 3  4183.00
# 101          10362                22      100.00                 4  3664.10
# 136          10140                26      100.00                 4  3188.12
# 215          10140                38      100.00                 8  4829.80
# 261          10362                22      100.00                 1  3877.06
# 423          10140                32      100.00                10  4181.44
# 756          10140                46       61.99                 2  2851.54
# 785          10168                21       70.96                 9  1490.16
# ...

# %% [markdown]
# ## data cleaning

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ORDER_NUMBER, QUANTITY_ORDERED, PRICE_EACH, ORDERLINE_NUMBER, SALES, ORDER_DATE, STATUS, QTR, MONTH, YEAR, PRODUCT_LINE, MSRP, PRODUCT_CODE, CUSTOMER_NAME, PHONE, ADDRESS_LINE, ADDRESSLINE2, CITY, STATE, POSTAL_CODE, COUNTRY, TERRITORY, CONTACT_LASTNAME, CONTACT_FIRSTNAME, DEAL_SIZE]
# Index: []
#
# [0 rows x 25 columns]

# %%
df1.isnull().sum()
# Out:
# ORDER_NUMBER         0
# QUANTITY_ORDERED     0
# PRICE_EACH           0
# ORDERLINE_NUMBER     0
# SALES                0
# ORDER_DATE           0
# STATUS               0
# QTR                  0
# MONTH                0
# YEAR                 0
# PRODUCT_LINE         0
# MSRP                 0
# PRODUCT_CODE         0
# CUSTOMER_NAME        0
# PHONE                0
# ADDRESS_LINE         0
# ADDRESSLINE2         0
# CITY                 0
# STATE                0
# POSTAL_CODE          0
# COUNTRY              0
# TERRITORY            0
# CONTACT_LASTNAME     0
# CONTACT_FIRSTNAME    0
# DEAL_SIZE            0
# dtype: int64

# %%
df1 = df.fillna('Not_applicable')
df1
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1168\3908829940.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1 = df.fillna('Not_applicable')
#       order_number  quantity_ordered  price_each  orderline_number    sales  \
# 0            10107                30       95.70                 2  2871.00
# 1            10121                34       81.35                 5  2765.90
# 2            10134                41       94.74                 2  3884.34
# 3            10145                45       83.26                 6  3746.70
# 4            10159                49      100.00                14  5205.27
# ...            ...               ...         ...               ...      ...
# 2818         10350                20      100.00                15  2244.40
# ...

# %%
df1
# Out:
#       order_number  quantity_ordered  price_each  orderline_number    sales  \
# 0            10107                30       95.70                 2  2871.00
# 1            10121                34       81.35                 5  2765.90
# 2            10134                41       94.74                 2  3884.34
# 3            10145                45       83.26                 6  3746.70
# 4            10159                49      100.00                14  5205.27
# ...            ...               ...         ...               ...      ...
# 2818         10350                20      100.00                15  2244.40
# 2819         10373                29      100.00                 1  3978.51
# 2820         10386                43      100.00                 4  5417.57
# 2821         10397                34       62.24                 1  2116.16
# 2822         10414                47       65.52                 9  3079.44
#
# ...

# %%
df2 = df1.drop(columns = 'addressline2')
df2
# Out:
#       order_number  quantity_ordered  price_each  orderline_number    sales  \
# 0            10107                30       95.70                 2  2871.00
# 1            10121                34       81.35                 5  2765.90
# 2            10134                41       94.74                 2  3884.34
# 3            10145                45       83.26                 6  3746.70
# 4            10159                49      100.00                14  5205.27
# ...            ...               ...         ...               ...      ...
# 2818         10350                20      100.00                15  2244.40
# 2819         10373                29      100.00                 1  3978.51
# 2820         10386                43      100.00                 4  5417.57
# 2821         10397                34       62.24                 1  2116.16
# 2822         10414                47       65.52                 9  3079.44
#
# ...

# %%
df2.isnull().sum()
# Out:
# order_number         0
# quantity_ordered     0
# price_each           0
# orderline_number     0
# sales                0
# order_date           0
# status               0
# qtr                  0
# month                0
# year                 0
# product_line         0
# msrp                 0
# product_code         0
# customer_name        0
# phone                0
# address_line         0
# city                 0
# state                0
# postal_code          0
# country              0
# territory            0
# contact_lastname     0
# contact_firstname    0
# deal_size            0
# dtype: int64

# %% [markdown]
# ## filtering functions

# %%
df5 = df2.query('price_each >= 90')
df5
# Out:
#       order_number  quantity_ordered  price_each  orderline_number    sales  \
# 0            10107                30       95.70                 2  2871.00
# 2            10134                41       94.74                 2  3884.34
# 4            10159                49      100.00                14  5205.27
# 5            10168                36       96.66                 1  3479.76
# 7            10188                48      100.00                 1  5512.32
# ...            ...               ...         ...               ...      ...
# 2791         10361                23       95.20                12  2189.60
# 2817         10337                42       97.16                 5  4080.72
# 2818         10350                20      100.00                15  2244.40
# 2819         10373                29      100.00                 1  3978.51
# 2820         10386                43      100.00                 4  5417.57
#
# ...

# %%
price_high = df2.groupby('price_each')['sales'].std().reset_index(name = 'high_price')
price_high.sort_values(by = 'high_price', ascending = False, ignore_index = True)
# Out:
#       price_each   high_price
# 0          93.28  5012.877962
# 1          92.00  2927.422074
# 2          88.75  2488.695169
# 3          90.19  2295.862581
# 4          98.18  1986.376569
# ...          ...          ...
# 1011       99.66          NaN
# 1012       99.67          NaN
# 1013       99.69          NaN
# 1014       99.72          NaN
# 1015       99.91          NaN
#
# [1016 rows x 2 columns]

# %%
price_high1 = df2.groupby('price_each')['sales'].mean().reset_index(name = 'high_price_avg')
price_high1.sort_values(by = 'high_price_avg', ascending = False, ignore_index = True)
# Out:
#       price_each  high_price_avg
# 0          92.95         6134.70
# 1          94.50         5811.75
# 2          93.28         5503.52
# 3          96.30         5296.50
# 4          92.00         5014.00
# ...          ...             ...
# 1011       35.18          703.60
# 1012       30.20          694.60
# 1013       43.49          652.35
# 1014       32.59          651.80
# 1015       28.88          577.60
#
# [1016 rows x 2 columns]

# %% [markdown]
# ## sorting functions

# %%
df2.sort_values(by = 'sales', ascending = False)
# Out:
#       order_number  quantity_ordered  price_each  orderline_number     sales  \
# 598          10407                76      100.00                 2  14082.80
# 744          10322                50      100.00                 6  12536.50
# 53           10424                50      100.00                 6  12001.00
# 1062         10412                60      100.00                 9  11887.80
# 104          10403                66      100.00                 9  11886.60
# ...            ...               ...         ...               ...       ...
# 1818         10419                15       42.67                 7    640.05
# 1551         10280                20       28.88                12    577.60
# 2044         10408                15       36.93                 1    553.95
# 1287         10407                 6       90.19                 3    541.14
# 2249         10425                11       43.83                 6    482.13
#
# ...

# %%
 import pymysql
from sqlalchemy import create_engine

engine_mysql = create_engine("mysql+pymysql://root:2005@127.0.0.1:3306/analysis_sales")

try:
    create_engine
    print("engine sucessfully active")
except:
    print("unable to connect")
# Out:
# engine sucessfully active

# %%
df2.to_sql(name = 'analysis_sales' , con = engine_mysql , if_exists= 'append' , index = False )
# Out:
# 2823
